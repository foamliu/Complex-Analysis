# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
z = np.linspace(-np.pi/2, np.pi/2)
plt.axis('equal')
plt.plot(z.real,z.imag)

# %%
f = np.sin(x)
plt.plot(f.real,f.imag)

# %%
z = np.linspace(-5j, 5j)
plt.plot(z.real,z.imag)

# %%
f = np.sin(z)
plt.plot(f.real,f.imag)

# %%
z=np.linspace(-np.pi/2-1j,-np.pi/2+1j)
plt.axis('equal')
plt.plot(z.real,z.imag)

# %%
f = np.sin(z)
plt.plot(f.real,f.imag)

# %%
z=np.linspace(np.pi/2-1j,np.pi/2+1j)
plt.plot(z.real,z.imag)

# %%
f = np.sin(z)
plt.grid()
plt.plot(f.real,f.imag)

# %%
t=np.linspace(0,2*np.pi)
z=np.exp(-t*1j)-1
plt.axis('equal')
plt.grid()
plt.plot(z.real,z.imag)

# %%
f=z*z
plt.plot(f.real,f.imag)
plt.grid()
plt.axis('equal')
# Out:
# (-0.7236736381711756,
#  4.2120310106332095,
#  -2.8527079540772515,
#  2.8527079540772515)

# %%
t=np.linspace(-np.pi,np.pi,num=500000)
z=np.sqrt(np.cos(2*t))*np.exp(-1j*t)
plt.plot(z.real,z.imag)
plt.grid()
plt.axis('equal')
# Out:
# (-1.0999999999970391,
#  1.0999999999378212,
#  -0.3889087296500422,
#  0.38890872965004225)

# %%
t=np.linspace(0,3*np.pi,200)
z=t*np.exp(1j*t)
plt.axis('equal')
plt.grid()
plt.plot(z.real,z.imag)

# %%
from mpl_toolkits import mplot3d
def f(x, y):
    z = x + y*1j
    f = np.sin(z)
    res = np.array(f, np.int64)
    return res

x = np.linspace(-6., 6., 30)
y = np.linspace(-6., 6., 30)

X, Y = np.meshgrid(x, y)
Z = f(X, Y)
ax = plt.axes(projection='3d')
ax.plot_surface(X, Y, Z, rstride=1, cstride=1,
                cmap='viridis', edgecolor='none')
ax.set_title('surface');

ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z');
